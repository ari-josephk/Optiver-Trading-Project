# %%
import os
import glob
from joblib import Parallel, delayed
import pandas as pd
import numpy as np
import scipy as sc
from sklearn.model_selection import KFold
import warnings
warnings.filterwarnings('ignore')
from tqdm import tqdm
import joblib
from statsmodels.tsa.arima.model import ARIMA as ARIMA
from arch import arch_model
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 200)
pd.options.mode.chained_assignment = None

# %%
data_dir = '../input/optiver-trading-at-the-close/'

def gts_cv(date_ids, holdout_size):

    X = date_ids[['date_id']]
    groups = X['date_id'].values
    unique_date_ids = np.unique(groups)
    array_split_date_ids = np.array_split(unique_date_ids, len(unique_date_ids) // holdout_size)[::-1]

    #array_split_date_ids = np.flip(array_split_date_ids)

    for date_ids in array_split_date_ids:
        
        
        test_condition = X['date_id'].isin(np.array([date_ids[-1]]))
        val_index = X.loc[test_condition].index
        train_condition = X['date_id'].isin(date_ids)
        train_index = X.loc[train_condition].index
        train_index = pd.Index(set(train_index)- set(val_index))


        yield train_index, val_index


def mae(y_true, y_pred):
    return np.abs(y_true - y_pred).mean()


def feval_mae(y_pred, lgb_train):
    y_true = lgb_train.get_label()
    return 'MAE', mae(y_true, y_pred), False



def train_and_evaluate_ARIMA(train):
 
    train = train[train['stock_id'] == 0]
    date_ids_train = train[['date_id','target']].reset_index(drop=True)

    cvs_dict = {'Fold': [],  'MAE_val': []}
    cv = gts_cv(date_ids_train, holdout_size=7)
    fold = 1
    for train_index, val_index in cv:

        target_train_cv, target_val_cv = date_ids_train.iloc[train_index], date_ids_train.iloc[val_index]

      
        print("训练集日期范围: {} -- {}".format(target_train_cv.date_id.min(),target_train_cv.date_id.max()))
        print("验证集日期范围: {} -- {}".format(target_val_cv.date_id.min(),target_val_cv.date_id.max()))
        
        target_train_cv =target_train_cv.drop(['date_id'], axis = 1)
        target_val_cv = target_val_cv.drop(['date_id'], axis = 1)


        model = ARIMA(target_train_cv, order=(2, 1, 6))  
        fitted = model.fit()  
        fc = fitted.forecast(len(target_val_cv)) 
        score=mae(fc.values,target_val_cv.values)
        #print(fc.values,score)
        cvs_dict['Fold'].append(fold)
        cvs_dict['MAE_val'].append(score)
        fold += 1
        
    print(f'CV Val MAE:',np.asarray(cvs_dict['MAE_val']).mean())

    return model

def train_and_evaluate_GARCH(train):
 
    train = train[train['stock_id'] == 0]
    date_ids_train = train[['date_id','target']].reset_index(drop=True)
    
    cvs_dict = {'Fold': [],  'MAE_val': []}
    cv = gts_cv(date_ids_train, holdout_size=30)
    fold = 1
    for train_index, val_index in cv:

        target_train_cv, target_val_cv = date_ids_train.iloc[train_index], date_ids_train.iloc[val_index]

      
        print("训练集日期范围: {} -- {}".format(target_train_cv.date_id.min(),target_train_cv.date_id.max()))
        print("验证集日期范围: {} -- {}".format(target_val_cv.date_id.min(),target_val_cv.date_id.max()))
        
        target_train_cv =target_train_cv.drop(['date_id'], axis = 1)
        target_val_cv = target_val_cv.drop(['date_id'], axis = 1)

        model = arch_model(target_train_cv, mean='Zero', vol='GARCH', p=2, q=6)
        model_fit = model.fit()
        yhat = model_fit.forecast(horizon=len(target_val_cv))
        score=mae(yhat.mean.values,target_val_cv.values)
        print(score)
        cvs_dict['Fold'].append(fold)
        cvs_dict['MAE_val'].append(score)
        fold += 1
        
    print(f'CV Val MAE:',np.asarray(cvs_dict['MAE_val']).mean())

    return model

# %%
dtypes = {
    'stock_id' : np.uint8,
    'date_id' : np.uint16,
    'seconds_in_bucket' : np.uint16,
    'imbalance_buy_sell_flag' : np.int8,
    'time_id' : np.uint16
    }
    
df = pd.read_csv('train.csv', dtype = dtypes)

# %%
train_and_evaluate_ARIMA(df)
# Out:
# 训练集日期范围: 474 -- 479
# 验证集日期范围: 480 -- 480
# 训练集日期范围: 467 -- 472
# 验证集日期范围: 473 -- 473
# 训练集日期范围: 460 -- 465
# 验证集日期范围: 466 -- 466
# 训练集日期范围: 453 -- 458
# 验证集日期范围: 459 -- 459
# 训练集日期范围: 446 -- 451
# 验证集日期范围: 452 -- 452
# 训练集日期范围: 439 -- 444
# 验证集日期范围: 445 -- 445
# 训练集日期范围: 432 -- 437
# 验证集日期范围: 438 -- 438
# 训练集日期范围: 425 -- 430
# 验证集日期范围: 431 -- 431
# 训练集日期范围: 418 -- 423
# 验证集日期范围: 424 -- 424
# 训练集日期范围: 411 -- 416
# 验证集日期范围: 417 -- 417
# 训练集日期范围: 404 -- 409
# 验证集日期范围: 410 -- 410
# 训练集日期范围: 397 -- 402
# 验证集日期范围: 403 -- 403
# 训练集日期范围: 390 -- 395
# 验证集日期范围: 396 -- 396
# 训练集日期范围: 383 -- 388
# 验证集日期范围: 389 -- 389
# 训练集日期范围: 376 -- 381
# 验证集日期范围: 382 -- 382
# 训练集日期范围: 369 -- 374
# 验证集日期范围: 375 -- 375
# 训练集日期范围: 362 -- 367
# 验证集日期范围: 368 -- 368
# 训练集日期范围: 355 -- 360
# 验证集日期范围: 361 -- 361
# 训练集日期范围: 348 -- 353
# 验证集日期范围: 354 -- 354
# 训练集日期范围: 341 -- 346
# 验证集日期范围: 347 -- 347
# 训练集日期范围: 334 -- 339
# 验证集日期范围: 340 -- 340
# 训练集日期范围: 327 -- 332
# 验证集日期范围: 333 -- 333
# 训练集日期范围: 320 -- 325
# 验证集日期范围: 326 -- 326
# 训练集日期范围: 313 -- 318
# 验证集日期范围: 319 -- 319
# 训练集日期范围: 306 -- 311
# 验证集日期范围: 312 -- 312
# 训练集日期范围: 299 -- 304
# 验证集日期范围: 305 -- 305
# 训练集日期范围: 292 -- 297
# 验证集日期范围: 298 -- 298
# 训练集日期范围: 285 -- 290
# 验证集日期范围: 291 -- 291
# 训练集日期范围: 278 -- 283
# 验证集日期范围: 284 -- 284
# 训练集日期范围: 271 -- 276
# 验证集日期范围: 277 -- 277
# 训练集日期范围: 264 -- 269
# 验证集日期范围: 270 -- 270
# 训练集日期范围: 257 -- 262
# 验证集日期范围: 263 -- 263
# 训练集日期范围: 250 -- 255
# 验证集日期范围: 256 -- 256
# 训练集日期范围: 243 -- 248
# 验证集日期范围: 249 -- 249
# 训练集日期范围: 236 -- 241
# 验证集日期范围: 242 -- 242
# 训练集日期范围: 229 -- 234
# 验证集日期范围: 235 -- 235
# 训练集日期范围: 222 -- 227
# 验证集日期范围: 228 -- 228
# 训练集日期范围: 215 -- 220
# 验证集日期范围: 221 -- 221
# 训练集日期范围: 208 -- 213
# 验证集日期范围: 214 -- 214
# 训练集日期范围: 201 -- 206
# 验证集日期范围: 207 -- 207
# 训练集日期范围: 194 -- 199
# 验证集日期范围: 200 -- 200
# 训练集日期范围: 187 -- 192
# 验证集日期范围: 193 -- 193
# 训练集日期范围: 180 -- 185
# 验证集日期范围: 186 -- 186
# 训练集日期范围: 173 -- 178
# 验证集日期范围: 179 -- 179
# 训练集日期范围: 166 -- 171
# 验证集日期范围: 172 -- 172
# 训练集日期范围: 159 -- 164
# 验证集日期范围: 165 -- 165
# 训练集日期范围: 152 -- 157
# 验证集日期范围: 158 -- 158
# 训练集日期范围: 145 -- 150
# 验证集日期范围: 151 -- 151
# 训练集日期范围: 138 -- 143
# 验证集日期范围: 144 -- 144
# 训练集日期范围: 131 -- 136
# 验证集日期范围: 137 -- 137
# 训练集日期范围: 124 -- 129
# 验证集日期范围: 130 -- 130
# 训练集日期范围: 117 -- 122
# 验证集日期范围: 123 -- 123
# 训练集日期范围: 110 -- 115
# 验证集日期范围: 116 -- 116
# 训练集日期范围: 103 -- 108
# 验证集日期范围: 109 -- 109
# 训练集日期范围: 96 -- 101
# 验证集日期范围: 102 -- 102
# 训练集日期范围: 89 -- 94
# 验证集日期范围: 95 -- 95
# 训练集日期范围: 82 -- 87
# 验证集日期范围: 88 -- 88
# 训练集日期范围: 75 -- 80
# 验证集日期范围: 81 -- 81
# 训练集日期范围: 68 -- 73
# 验证集日期范围: 74 -- 74
# 训练集日期范围: 61 -- 66
# 验证集日期范围: 67 -- 67
# 训练集日期范围: 54 -- 59
# 验证集日期范围: 60 -- 60
# 训练集日期范围: 47 -- 52
# 验证集日期范围: 53 -- 53
# 训练集日期范围: 40 -- 45
# 验证集日期范围: 46 -- 46
# 训练集日期范围: 32 -- 38
# 验证集日期范围: 39 -- 39
# 训练集日期范围: 24 -- 30
# 验证集日期范围: 31 -- 31
# 训练集日期范围: 16 -- 22
# 验证集日期范围: 23 -- 23
# 训练集日期范围: 8 -- 14
# 验证集日期范围: 15 -- 15
# 训练集日期范围: 0 -- 6
# 验证集日期范围: 7 -- 7
# CV Val MAE: 4.523104009389119

# %%
train_and_evaluate_GARCH(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\arikh\Coding\Optiver Trading\arima-and-garch-model-for-ts-cv.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/arikh/Coding/Optiver%20Trading/arima-and-garch-model-for-ts-cv.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> train_and_evaluate_GARCH(df)
#
# c:\Users\arikh\Coding\Optiver Trading\arima-and-garch-model-for-ts-cv.ipynb Cell 5 line 7
#      <a href='vscode-notebook-cell:/c%3A/Users/arikh/Coding/Optiver%20Trading/arima-and-garch-model-for-ts-cv.ipynb#W4sZmlsZQ%3D%3D?line=72'>73</a> cv = gts_cv(date_ids_train, holdout_size=30)
#      <a href='vscode-notebook-cell:/c%3A/Users/arikh/Coding/Optiver%20Trading/arima-and-garch-model-for-ts-cv.ipynb#W4sZmlsZQ%3D%3D?line=73'>74</a> fold = 1
# ---> <a href='vscode-notebook-cell:/c%3A/Users/arikh/Coding/Optiver%20Trading/arima-and-garch-model-for-ts-cv.ipynb#W4sZmlsZQ%3D%3D?line=74'>75</a> for train_index, val_index in cv:
#      <a href='vscode-notebook-cell:/c%3A/Users/arikh/Coding/Optiver%20Trading/arima-and-garch-model-for-ts-cv.ipynb#W4sZmlsZQ%3D%3D?line=76'>77</a>     target_train_cv, target_val_cv = date_ids_train.iloc[train_index], date_ids_train.iloc[val_index]
#      <a href='vscode-notebook-cell:/c%3A/Users/arikh/Coding/Optiver%20Trading/arima-and-garch-model-for-ts-cv.ipynb#W4sZmlsZQ%3D%3D?line=79'>80</a>     print("训练集日期范围: {} -- {}".format(target_train_cv.date_id.min(),target_train_cv.date_id.max()))
#
# c:\Users\arikh\Coding\Optiver Trading\arima-and-garch-model-for-ts-cv.ipynb Cell 5 line 9
#       <a href='vscode-notebook-cell:/c%3A/Users/arikh/Coding/Optiver%20Trading/arima-and-garch-model-for-ts-cv.ipynb#W4sZmlsZQ%3D%3D?line=6'>7</a> unique_date_ids = np.unique(groups)
#       <a href='vscode-notebook-cell:/c%3A/Users/arikh/Coding/Optiver%20Trading/arima-and-garch-model-for-ts-cv.ipynb#W4sZmlsZQ%3D%3D?line=7'>8</a> array_split_date_ids = np.array_split(unique_date_ids, len(unique_date_ids) // holdout_size)[::-1]
# ----> <a href='vscode-notebook-cell:/c%3A/Users/arikh/Coding/Optiver%20Trading/arima-and-garch-model-for-ts-cv.ipynb#W4sZmlsZQ%3D%3D?line=8'>9</a> array_split_date_ids = np.flip(array_split_date_ids)
#      <a href='vscode-notebook-cell:/c%3A/Users/arikh/Coding/Optiver%20Trading/arima-and-garch-model-for-ts-cv.ipynb#W4sZmlsZQ%3D%3D?line=10'>11</a> for date_ids in array_split_date_ids:
#      <a href='vscode-notebook-cell:/c%3A/Users/arikh/Coding/Optiver%20Trading/arima-and-garch-model-for-ts-cv.ipynb#W4sZmlsZQ%3D%3D?line=13'>14</a>     test_condition = X['date_id'].isin(np.array([date_ids[-1]]))
#
# File <__array_function__ internals>:200, in flip(*args, **kwargs)
#
# File c:\Users\arikh\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\function_base.py:334, in flip(m, axis)
#     254 """
#     255 Reverse the order of elements in an array along the given axis.
#     256
#    (...)
#     331 True
#     332 """
#     333 if not hasattr(m, 'ndim'):
# --> 334     m = asarray(m)
#     335 if axis is None:
#     336     indexer = (np.s_[::-1],) * m.ndim
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (16,) + inhomogeneous part.
