# %%
import gc  # Garbage collection for memory management
import os  # Operating system-related functions
import time  # Time-related functions
import warnings  # Handling warnings
from itertools import combinations  # For creating combinations of elements
from warnings import simplefilter  # Simplifying warning handling

import numpy as np  # Numerical operations
import pandas as pd  # Data manipulation and analysis

# Remove annoying warnings lol
simplefilter(action="ignore")

low_cpu_mode = True

# %%
df = pd.read_csv("train.csv")
df = df.dropna(subset=["target"])
df.reset_index(drop=True, inplace=True)
df_shape = df.shape

# %%
if low_cpu_mode:
	df = df.sample(n=100000)
	print(df.shape)
# Out:
# (100000, 17)

# %%
split_day = 435
df_train = df[df["date_id"] < split_day]
df_valid = df[df["date_id"] == split_day]

# Display a message indicating offline mode and the shapes of the training and validation sets
print(f"train : {df_train.shape}, valid : {df_valid.shape}")
# Out:
# train : (90350, 17), valid : (213, 17)

# %%
def create_timeseries(df):
    # Sort the DataFrame
    df.sort_values(by=['stock_id', 'date_id', 'seconds_in_bucket'], inplace=True)

    # Create a MultiIndex from the unique values of date_id and seconds_in_bucket
    multi_index = pd.MultiIndex.from_product(
        [df['date_id'].unique(), df['seconds_in_bucket'].unique()],
        names=['date_id', 'seconds_in_bucket']
    )

    # Function to reindex each group
    def reindex_group(group):
        group.set_index(['date_id', 'seconds_in_bucket'], inplace=True)
        group = group.dropna(subset=['stock_id'])
        return group.reindex(multi_index).reset_index()

    # Group by stock_id and apply the reindexing function
    time_series_df = df.groupby('stock_id').apply(reindex_group).reset_index(drop=True)
    time_series_df = time_series_df.dropna(subset=['stock_id'])

    return time_series_df

time_series_df_train = create_timeseries(df_train)
time_series_df_valid = create_timeseries(df_valid)
time_series_df = create_timeseries(df)

# Display a message indicating offline mode and the shapes of the training and validation sets
print(f"train : {time_series_df_train.shape}, valid : {time_series_df_valid.shape}")
# Out:
# train : (90350, 17), valid : (213, 17)

# %%
import torch
import torch.nn as nn

loss = nn.L1Loss()

# %%
# OVERALL PREDICTION ATTEMPT

import statsmodels.api as sm
from statsmodels.tsa.arima.model import ARIMA
import itertools

# Parameter Search
p = d = q = range(0, 5)  
pdq = list(itertools.product(p, d, q))

best_aic = float("inf")
best_pdq = None
best_model = None

for param in pdq:
    try:
        sample_df = time_series_df_train[time_series_df_train['stock_id'] == 0]
        model = ARIMA(sample_df['target'], order=param)
        results = model.fit()

        if results.aic < best_aic:
            best_aic = results.aic
            best_pdq = param
            best_model = results
    except:
        continue

print(f"Best ARIMA{best_pdq} model with AIC: {best_aic}")


total_predictions = 0
total_loss = 0

# Iterate over each stock_id
for stock_id in time_series_df_train['stock_id'].unique():
    print(f"Processing stock_id: {stock_id}")

    try:
        # Filter data for the current stock_id
        df_stock = time_series_df_train[time_series_df_train['stock_id'] == stock_id]

        # Fit ARIMA model (using differenced data if necessary)
        model = ARIMA(df_stock['target'].dropna(), order=best_pdq)
        results = model.fit()

        valid_targets = time_series_df_valid[time_series_df_valid['stock_id'] == stock_id]['target'].dropna()

        forecast = results.forecast(steps=len(valid_targets))
        
        total_predictions += 1
        mae_loss = loss(torch.tensor(forecast.values), torch.tensor(valid_targets.values)).item()
        total_loss += mae_loss

        print(f'Current MAE: {mae_loss}. Rolling MAE Loss: {total_loss / total_predictions}')
    except:
        print('Error in predicting stock')

print(f'Final MAE: {total_loss / total_predictions}')
# Out:
# Best ARIMA(2, 0, 3) model with AIC: 2922.9557616292586
# Processing stock_id: 0.0
# Current MAE: 4.105270747428987. Rolling MAE Loss: 4.105270747428987
# Processing stock_id: 1.0
# Current MAE: 4.9150880123501235. Rolling MAE Loss: 4.510179379889555
# Processing stock_id: 2.0
# Current MAE: 6.14368855058773. Rolling MAE Loss: 5.054682436788947
# Processing stock_id: 3.0
# Current MAE: 0.8018717618161673. Rolling MAE Loss: 3.991479768045752
# Processing stock_id: 4.0
# Current MAE: 4.152122369942367. Rolling MAE Loss: 4.023608288425075
# Processing stock_id: 5.0
# Current MAE: 3.500529195737872. Rolling MAE Loss: 3.9364284396438745
# Processing stock_id: 6.0
# Error in predicting stock
# Processing stock_id: 7.0
# Error in predicting stock
# Processing stock_id: 8.0
# Error in predicting stock
# Processing stock_id: 9.0
# Current MAE: 3.7021879345285287. Rolling MAE Loss: 3.9029655103416823
# Processing stock_id: 10.0
# Error in predicting stock
# Processing stock_id: 11.0
# Current MAE: 9.020639626734864. Rolling MAE Loss: 4.54267477489083
# Processing stock_id: 12.0
# Error in predicting stock
# Processing stock_id: 13.0
# Current MAE: 10.648037438836447. Rolling MAE Loss: 5.22104840421812
# Processing stock_id: 14.0
# Current MAE: 0.4484366007664714. Rolling MAE Loss: 4.743787223872955
# Processing stock_id: 15.0
# Current MAE: 5.169017020420775. Rolling MAE Loss: 4.782444478104575
# Processing stock_id: 16.0
# Error in predicting stock
# Processing stock_id: 17.0
# Error in predicting stock
# Processing stock_id: 18.0
# Error in predicting stock
# Processing stock_id: 19.0
# Current MAE: 1.6365364605383121. Rolling MAE Loss: 4.52028547664072
# Processing stock_id: 20.0
# Error in predicting stock
# Processing stock_id: 21.0
# Current MAE: 7.187982138563495. Rolling MAE Loss: 4.725492912173241
# Processing stock_id: 22.0
# Error in predicting stock
# Processing stock_id: 23.0
# Error in predicting stock
# Processing stock_id: 24.0
# Current MAE: 2.8180974946533768. Rolling MAE Loss: 4.589250382350393
# Processing stock_id: 25.0
# Current MAE: 14.301531293861599. Rolling MAE Loss: 5.23673577645114
# Processing stock_id: 26.0
# Error in predicting stock
# Processing stock_id: 27.0
# Current MAE: 20.295334335032386. Rolling MAE Loss: 6.177898186362468
# Processing stock_id: 28.0
# Current MAE: 0.22710385971431157. Rolling MAE Loss: 5.827851461265517
# Processing stock_id: 29.0
# Error in predicting stock
# Processing stock_id: 30.0
# Current MAE: 10.581957236874846. Rolling MAE Loss: 6.091968448799368
# Processing stock_id: 31.0
# Current MAE: 27.9441532795926. Rolling MAE Loss: 7.242083439893749
# Processing stock_id: 32.0
# Error in predicting stock
# Processing stock_id: 33.0
# Error in predicting stock
# Processing stock_id: 34.0
# Current MAE: 3.1546444147047263. Rolling MAE Loss: 7.037711488634298
# Processing stock_id: 35.0
# Error in predicting stock
# Processing stock_id: 36.0
# Current MAE: 14.011549796768383. Rolling MAE Loss: 7.369799027116874
# Processing stock_id: 37.0
# Error in predicting stock
# Processing stock_id: 38.0
# Current MAE: 2.558881612556627. Rolling MAE Loss: 7.1511209628186805
# Processing stock_id: 39.0
# Current MAE: 9.609059978891887. Rolling MAE Loss: 7.2579878765609935
# Processing stock_id: 40.0
# Current MAE: 2.005803184145123. Rolling MAE Loss: 7.039146847710332
# Processing stock_id: 41.0
# Current MAE: 4.552954815010983. Rolling MAE Loss: 6.939699166402359
# Processing stock_id: 42.0
# Error in predicting stock
# Processing stock_id: 43.0
# Current MAE: 8.574663518763114. Rolling MAE Loss: 7.002582410723926
# Processing stock_id: 44.0
# Error in predicting stock
# Processing stock_id: 45.0
# Current MAE: 0.473426101936007. Rolling MAE Loss: 6.760761806694744
# Processing stock_id: 46.0
# Current MAE: 5.5426498399578445. Rolling MAE Loss: 6.717257807882712
# Processing stock_id: 47.0
# Current MAE: 3.0709468338490398. Rolling MAE Loss: 6.591522946709137
# Processing stock_id: 48.0
# Current MAE: 7.677379682115219. Rolling MAE Loss: 6.627718171222673
# Processing stock_id: 49.0
# Current MAE: 0.2938103402976271. Rolling MAE Loss: 6.423398563773478
# Processing stock_id: 50.0
# Current MAE: 2.3225796502522584. Rolling MAE Loss: 6.2952479727259405
# Processing stock_id: 51.0
# Current MAE: 4.776988037471958. Rolling MAE Loss: 6.2492400959000625
# Processing stock_id: 52.0
# Current MAE: 3.1214578788444944. Rolling MAE Loss: 6.157246501280781
# Processing stock_id: 53.0
# Current MAE: 3.0885829908254245. Rolling MAE Loss: 6.069570400982056
# Processing stock_id: 54.0
# Error in predicting stock
# Processing stock_id: 55.0
# Current MAE: 0.19274687981074445. Rolling MAE Loss: 5.906325303171743
# Processing stock_id: 56.0
# Current MAE: 8.684224802577415. Rolling MAE Loss: 5.981403668020544
# Processing stock_id: 57.0
# Current MAE: 0.6466785155569348. Rolling MAE Loss: 5.8410161640083444
# Processing stock_id: 58.0
# Error in predicting stock
# Processing stock_id: 59.0
# Current MAE: 4.812648589223508. Rolling MAE Loss: 5.814647764654887
# Processing stock_id: 60.0
# Current MAE: 4.842582192500194. Rolling MAE Loss: 5.79034612535102
# Processing stock_id: 61.0
# Error in predicting stock
# Processing stock_id: 62.0
# Current MAE: 12.195956401843748. Rolling MAE Loss: 5.946580522338647
# Processing stock_id: 63.0
# Current MAE: 3.60744209287607. Rolling MAE Loss: 5.890886750208585
# Processing stock_id: 64.0
# Current MAE: 1.0966705654724678. Rolling MAE Loss: 5.779393350563559
# Processing stock_id: 65.0
# Current MAE: 5.447800287039618. Rolling MAE Loss: 5.771857144574379
# Processing stock_id: 66.0
# Error in predicting stock
# Processing stock_id: 67.0
# Current MAE: 10.59741071710615. Rolling MAE Loss: 5.879091668408418
# Processing stock_id: 68.0
# Error in predicting stock
# Processing stock_id: 69.0
# Current MAE: 0.46793271905849076. Rolling MAE Loss: 5.761457778205158
# Processing stock_id: 70.0
# Error in predicting stock
# Processing stock_id: 71.0
# Current MAE: 3.8406626330246945. Rolling MAE Loss: 5.720589796392808
# Processing stock_id: 72.0
# Error in predicting stock
# Processing stock_id: 73.0
# Error in predicting stock
# Processing stock_id: 74.0
# Current MAE: 2.089142606728146. Rolling MAE Loss: 5.644934646608128
# Processing stock_id: 75.0
# Current MAE: 2.490992395737128. Rolling MAE Loss: 5.580568478223006
# Processing stock_id: 76.0
# Current MAE: 21.543407433778576. Rolling MAE Loss: 5.899825257334117
# Processing stock_id: 77.0
# Current MAE: 17.082364200685447. Rolling MAE Loss: 6.119090726811594
# Processing stock_id: 78.0
# Current MAE: 7.395252019387825. Rolling MAE Loss: 6.143632290130368
# Processing stock_id: 79.0
# Current MAE: 19.952152104216868. Rolling MAE Loss: 6.404170399830113
# Processing stock_id: 80.0
# Error in predicting stock
# Processing stock_id: 81.0
# Current MAE: 2.669632963904639. Rolling MAE Loss: 6.335012299164826
# Processing stock_id: 82.0
# Current MAE: 31.891518079542994. Rolling MAE Loss: 6.799676040626247
# Processing stock_id: 83.0
# Current MAE: 1.3900484034117857. Rolling MAE Loss: 6.703075547104561
# Processing stock_id: 84.0
# Error in predicting stock
# Processing stock_id: 85.0
# Current MAE: 5.873140807595071. Rolling MAE Loss: 6.688515288516675
# Processing stock_id: 86.0
# Error in predicting stock
# Processing stock_id: 87.0
# Error in predicting stock
# Processing stock_id: 88.0
# Current MAE: 1.109726540489818. Rolling MAE Loss: 6.59232927561966
# Processing stock_id: 89.0
# Current MAE: 3.2790368939747743. Rolling MAE Loss: 6.536171777625679
# Processing stock_id: 90.0
# Error in predicting stock
# Processing stock_id: 91.0
# Error in predicting stock
# Processing stock_id: 92.0
# Error in predicting stock
# Processing stock_id: 93.0
# Current MAE: 8.035743086158815. Rolling MAE Loss: 6.561164632767897
# Processing stock_id: 94.0
# Current MAE: 6.981301399792318. Rolling MAE Loss: 6.568052120751904
# Processing stock_id: 95.0
# Current MAE: 0.1483358719701161. Rolling MAE Loss: 6.464508310287681
# Processing stock_id: 96.0
# Current MAE: 16.57433701271395. Rolling MAE Loss: 6.624981781754765
# Processing stock_id: 97.0
# Current MAE: 8.32311596014446. Rolling MAE Loss: 6.651515128292104
# Processing stock_id: 98.0
# Error in predicting stock
# Processing stock_id: 99.0
# Error in predicting stock
# Processing stock_id: 100.0
# Current MAE: 2.8114914677905043. Rolling MAE Loss: 6.592437841207464
# Processing stock_id: 101.0
# Current MAE: 2.6791145322231906. Rolling MAE Loss: 6.533145063798612
# Processing stock_id: 102.0
# Current MAE: 10.854085275451542. Rolling MAE Loss: 6.597636708748656
# Processing stock_id: 103.0
# Error in predicting stock
# Processing stock_id: 104.0
# Current MAE: 2.292937279105195. Rolling MAE Loss: 6.534332305371546
# Processing stock_id: 105.0
# Error in predicting stock
# Processing stock_id: 106.0
# Error in predicting stock
# Processing stock_id: 107.0
# Current MAE: 6.342684451154762. Rolling MAE Loss: 6.531554800237969
# Processing stock_id: 108.0
# Current MAE: 5.737260480380476. Rolling MAE Loss: 6.52020773852572
# Processing stock_id: 109.0
# Current MAE: 3.2008868418495164. Rolling MAE Loss: 6.473456739980985
# Processing stock_id: 110.0
# Current MAE: 11.079078319786596. Rolling MAE Loss: 6.537423706367174
# Processing stock_id: 111.0
# Error in predicting stock
# Processing stock_id: 112.0
# Current MAE: 1.925615156018769. Rolling MAE Loss: 6.47424824677336
# Processing stock_id: 113.0
# Error in predicting stock
# Processing stock_id: 114.0
# Current MAE: 6.591818660891542. Rolling MAE Loss: 6.475837036153335
# Processing stock_id: 115.0
# Current MAE: 2.5924368231538257. Rolling MAE Loss: 6.424058366646675
# Processing stock_id: 116.0
# Error in predicting stock
# Processing stock_id: 117.0
# Current MAE: 3.3106748765850984. Rolling MAE Loss: 6.3830927944090226
# Processing stock_id: 118.0
# Error in predicting stock
# Processing stock_id: 119.0
# Error in predicting stock
# Processing stock_id: 120.0
# Current MAE: 4.1411093301881365. Rolling MAE Loss: 6.353976126042518
# Processing stock_id: 121.0
# Error in predicting stock
# Processing stock_id: 122.0
# Error in predicting stock
# Processing stock_id: 123.0
# Current MAE: 3.6490430998114833. Rolling MAE Loss: 6.319297497501094
# Processing stock_id: 124.0
# Current MAE: 0.7726930176072266. Rolling MAE Loss: 6.249087314211299
# Processing stock_id: 125.0
# Error in predicting stock
# Processing stock_id: 126.0
# Error in predicting stock
# Processing stock_id: 127.0
# Error in predicting stock
# Processing stock_id: 128.0
# Current MAE: 5.921176019753816. Rolling MAE Loss: 6.2449884230305805
# Processing stock_id: 129.0
# Current MAE: 2.355785289262384. Rolling MAE Loss: 6.19697356952727
# Processing stock_id: 130.0
# Current MAE: 2.571936706373966. Rolling MAE Loss: 6.152765802903448
# Processing stock_id: 131.0
# Current MAE: 2.147393469623026. Rolling MAE Loss: 6.104508304912118
# Processing stock_id: 132.0
# Current MAE: 1.7494988093152326. Rolling MAE Loss: 6.0526629537740595
# Processing stock_id: 133.0
# Current MAE: 3.0215132463867382. Rolling MAE Loss: 6.0170023689812675
# Processing stock_id: 134.0
# Error in predicting stock
# Processing stock_id: 135.0
# Current MAE: 11.220295336154958. Rolling MAE Loss: 6.07750577557631
# Processing stock_id: 136.0
# Current MAE: 0.8250478444322904. Rolling MAE Loss: 6.017132695907989
# Processing stock_id: 137.0
# Current MAE: 12.15726742540781. Rolling MAE Loss: 6.086906954197759
# Processing stock_id: 138.0
# Current MAE: 2.0628791159339657. Rolling MAE Loss: 6.041693158262211
# Processing stock_id: 139.0
# Current MAE: 1.7777466161774527. Rolling MAE Loss: 5.994315974461268
# Processing stock_id: 140.0
# Error in predicting stock
# Processing stock_id: 141.0
# Current MAE: 2.9126012309918177. Rolling MAE Loss: 5.960450977280286
# Processing stock_id: 142.0
# Current MAE: 6.703535221315369. Rolling MAE Loss: 5.9685279799328415
# Processing stock_id: 143.0
# Current MAE: 4.572308074026913. Rolling MAE Loss: 5.953514862665036
# Processing stock_id: 144.0
# Current MAE: 5.345504291230617. Rolling MAE Loss: 5.947046665096584
# Processing stock_id: 145.0
# Current MAE: 2.2961456233188695. Rolling MAE Loss: 5.908616127814715
# Processing stock_id: 146.0
# Current MAE: 0.34632970095283. Rolling MAE Loss: 5.85067564420157
# Processing stock_id: 147.0
# Current MAE: 2.487468895555727. Rolling MAE Loss: 5.816003409679448
# Processing stock_id: 148.0
# Current MAE: 4.7054033648815015. Rolling MAE Loss: 5.8046707561611015
# Processing stock_id: 149.0
# Current MAE: 0.6173822948683739. Rolling MAE Loss: 5.75227390301673
# Processing stock_id: 150.0
# Current MAE: 5.202263513074356. Rolling MAE Loss: 5.746773799117307
# Processing stock_id: 151.0
# Current MAE: 5.8752720933342735. Rolling MAE Loss: 5.7480460594560885
# Processing stock_id: 152.0
# Current MAE: 15.338715446993536. Rolling MAE Loss: 5.842072229922142
# Processing stock_id: 153.0
# Current MAE: 23.030996724942696. Rolling MAE Loss: 6.008954992009721
# Processing stock_id: 154.0
# Error in predicting stock
# Processing stock_id: 155.0
# Error in predicting stock
# Processing stock_id: 156.0
# Error in predicting stock
# Processing stock_id: 157.0
# Current MAE: 3.539448925053817. Rolling MAE Loss: 5.985209741365913
# Processing stock_id: 158.0
# Error in predicting stock
# Processing stock_id: 159.0
# Current MAE: 7.424126221651164. Rolling MAE Loss: 5.99891370784482
# Processing stock_id: 160.0
# Current MAE: 2.203743560978161. Rolling MAE Loss: 5.963110215893248
# Processing stock_id: 161.0
# Current MAE: 4.2425836116556574. Rolling MAE Loss: 5.947030528003177
# Processing stock_id: 162.0
# Current MAE: 11.103970890901635. Rolling MAE Loss: 5.994779975807792
# Processing stock_id: 163.0
# Error in predicting stock
# Processing stock_id: 164.0
# Current MAE: 2.237982333821531. Rolling MAE Loss: 5.960313942395074
# Processing stock_id: 165.0
# Error in predicting stock
# Processing stock_id: 166.0
# Current MAE: 1.211521744007271. Rolling MAE Loss: 5.917143104227913
# Processing stock_id: 167.0
# Error in predicting stock
# Processing stock_id: 168.0
# Error in predicting stock
# Processing stock_id: 169.0
# Current MAE: 6.7105242050509855. Rolling MAE Loss: 5.924290681712805
# Processing stock_id: 170.0
# Error in predicting stock
# Processing stock_id: 171.0
# Current MAE: 8.864878074935351. Rolling MAE Loss: 5.95054592629515
# Processing stock_id: 172.0
# Current MAE: 3.9613879929637323. Rolling MAE Loss: 5.932942758743545
# Processing stock_id: 173.0
# Error in predicting stock
# Processing stock_id: 174.0
# Current MAE: 14.535698585575275. Rolling MAE Loss: 6.008405529154349
# Processing stock_id: 175.0
# Current MAE: 2.8898329527184736. Rolling MAE Loss: 5.981287506750559
# Processing stock_id: 176.0
# Current MAE: 7.535895068155599. Rolling MAE Loss: 5.994689296073016
# Processing stock_id: 177.0
# Current MAE: 1.4441672115103479. Rolling MAE Loss: 5.955795944922908
# Processing stock_id: 178.0
# Current MAE: 18.247976959828158. Rolling MAE Loss: 6.059966970472953
# Processing stock_id: 179.0
# Current MAE: 11.253249175204157. Rolling MAE Loss: 6.103607997403467
# Processing stock_id: 180.0
# Error in predicting stock
# Processing stock_id: 181.0
# Error in predicting stock
# Processing stock_id: 182.0
# Error in predicting stock
# Processing stock_id: 183.0
# Current MAE: 0.1652580264327706. Rolling MAE Loss: 6.054121747645378
# Processing stock_id: 184.0
# Error in predicting stock
# Processing stock_id: 185.0
# Current MAE: 4.46253684099761. Rolling MAE Loss: 6.0409681533755615
# Processing stock_id: 186.0
# Current MAE: 2.6768641180114217. Rolling MAE Loss: 6.013393530134871
# Processing stock_id: 187.0
# Error in predicting stock
# Processing stock_id: 188.0
# Error in predicting stock
# Processing stock_id: 189.0
# Current MAE: 7.533218213408269. Rolling MAE Loss: 6.0257498283728665
# Processing stock_id: 190.0
# Error in predicting stock
# Processing stock_id: 191.0
# Error in predicting stock
# Processing stock_id: 192.0
# Current MAE: 6.761069464935879. Rolling MAE Loss: 6.031679825441923
# Processing stock_id: 193.0
# Error in predicting stock
# Processing stock_id: 194.0
# Error in predicting stock
# Processing stock_id: 195.0
# Current MAE: 1.5137149065168547. Rolling MAE Loss: 5.995536106090523
# Processing stock_id: 196.0
# Current MAE: 14.660106652828727. Rolling MAE Loss: 6.064302539001143
# Processing stock_id: 197.0
# Current MAE: 8.061284848801304. Rolling MAE Loss: 6.08002680915705
# Processing stock_id: 198.0
# Current MAE: 2.2597051415191043. Rolling MAE Loss: 6.050180546128629
# Processing stock_id: 199.0
# Current MAE: 1.536420504272267. Rolling MAE Loss: 6.015190158207262
# Final MAE: 6.015190158207262

# %%
# INDIVIDUAL STOCK 
test_stock_id = 6


# Parameter Search
p = q = range(0, 5)
d = range(0, 1)  
pdq = list(itertools.product(p, d, q))

best_aic = float("inf")
best_pdq = None
best_model = None

for param in pdq:
    try:
        sample_df = time_series_df[time_series_df['stock_id'] == test_stock_id]
        model = ARIMA(sample_df['target'], order=param)
        results = model.fit()

        if results.aic < best_aic:
            best_aic = results.aic
            best_pdq = param
            best_model = results
    except:
        continue


print(f"Best ARIMA{best_pdq} model with AIC: {best_aic}")

n_splits = 5

# Calculate the size of each fold (using K-fold val)
df_stock = time_series_df[time_series_df['stock_id'] == test_stock_id]
n_samples = len(df_stock)
fold_size = n_samples // n_splits
scores = []

print(n_samples, fold_size)


print(f"Processing stock_id: {test_stock_id}")

for i in range(n_splits):
    train = df_stock.iloc[:i * fold_size + fold_size]
    test = df.iloc[i * fold_size + fold_size:(i + 1) * fold_size + fold_size]

    model = ARIMA(train['target'], order=best_pdq) 
    results = model.fit()

    test_targets = test['target'].dropna()
    forecast = results.forecast(steps=len(test))


    # Evaluate the model
    mae_loss = loss(torch.tensor(forecast.values), torch.tensor(test_targets.values)).item()
    print(f'Fold {i} Loss: {mae_loss}')
    scores.append(mae_loss)

# Calculate average score
average_score = np.mean(scores)
print(f"Average Score: {average_score}")
# Out:
# Best ARIMA(0, 0, 0) model with AIC: 3375.112843739838
# 473 94
# Processing stock_id: 6
# Fold 0 Loss: 5.014735106348673
# Fold 1 Loss: 5.022173192045805
# Fold 2 Loss: 3.9358587830444627
# Fold 3 Loss: 4.17663872913984
# Fold 4 Loss: 4.387835446347974
# Average Score: 4.507448251385351

# %%
# Function to generate imbalance features
def imbalance_features(df):
    # Define lists of price and size-related column names
    prices = ["reference_price", "far_price", "near_price", "ask_price", "bid_price", "wap"]
    sizes = ["matched_size", "bid_size", "ask_size", "imbalance_size"]

    # V1 features
    # Calculate various features using Pandas eval function
    df["volume"] = df.eval("ask_size + bid_size")
    df["mid_price"] = df.eval("(ask_price + bid_price) / 2")
    df["liquidity_imbalance"] = df.eval("(bid_size-ask_size)/(bid_size+ask_size)")
    df["matched_imbalance"] = df.eval("(imbalance_size-matched_size)/(matched_size+imbalance_size)")
    df["size_imbalance"] = df.eval("bid_size / ask_size")
    
    # Create features for pairwise price imbalances
    for c in combinations(prices, 2):
        df[f"{c[0]}_{c[1]}_imb"] = df.eval(f"({c[0]} - {c[1]})/({c[0]} + {c[1]})")

    # Calculate additional features
    df["imbalance_momentum"] = df.groupby(['stock_id'])['imbalance_size'].diff(periods=1) / df['matched_size']
    df["price_spread"] = df["ask_price"] - df["bid_price"]
    df["spread_intensity"] = df.groupby(['stock_id'])['price_spread'].diff()
    df['price_pressure'] = df['imbalance_size'] * (df['ask_price'] - df['bid_price'])
    df['market_urgency'] = df['price_spread'] * df['liquidity_imbalance']
    df['depth_pressure'] = (df['ask_size'] - df['bid_size']) * (df['far_price'] - df['near_price'])
    
    # Calculate various statistical aggregation features
    for func in ["mean", "std", "skew", "kurt"]:
        df[f"all_prices_{func}"] = df[prices].agg(func, axis=1)
        df[f"all_sizes_{func}"] = df[sizes].agg(func, axis=1)
        
    # Calculate shifted and return features for specific columns
    for col in ['matched_size', 'imbalance_size', 'reference_price', 'imbalance_buy_sell_flag']:
        for window in [1, 2, 3, 10]:
            df[f"{col}_shift_{window}"] = df.groupby('stock_id')[col].shift(window)
            df[f"{col}_ret_{window}"] = df.groupby('stock_id')[col].pct_change(window)
    
    # Calculate diff features for specific columns
    for col in ['ask_price', 'bid_price', 'ask_size', 'bid_size']:
        for window in [1, 2, 3, 10]:
            df[f"{col}_diff_{window}"] = df.groupby("stock_id")[col].diff(window)

    # Replace infinite values with 0
    return df.replace([np.inf, -np.inf], 0)

# Function to generate time and stock-related features
def other_features(df):
    df["dow"] = df["date_id"] % 5  # Day of the week
    df["seconds"] = df["seconds_in_bucket"] % 60  # Seconds
    df["minute"] = df["seconds_in_bucket"] // 60  # Minutes
    
    return df

# Function to generate all features by combining imbalance and other features
def generate_all_features(df):
    
    # Generate imbalance features
    df = imbalance_features(df)
    df = other_features(df)
    #gc.collect()  # Perform garbage collection to free up memory
    
    return df
